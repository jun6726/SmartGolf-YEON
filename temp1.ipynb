# %%
import tensorflow as tf
import keras as k
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
#jupyter Notebook 내부에 그래프를 출력하도록 설정
# %matplotlib inline
import seaborn as sns
# Out:
# Using TensorFlow backend.

# %%
swing_dir= "./swing/"
data = pd.read_csv(swing_dir+"golf1.csv")
for i in range(1,5):
    temp = pd.read_csv(swing_dir+"golf"+str(i+1)+".csv")
    data.append(data,temp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-0393b8cf51d0> in <module>
#       3 for i in range(1,5):
#       4     temp = pd.read_csv(swing_dir+"golf"+str(i+1)+".csv")
# ----> 5     data.append(data,temp)
#
# ~\Anaconda3\envs\venv_ml\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7114             ignore_index=ignore_index,
#    7115             verify_integrity=verify_integrity,
# -> 7116             sort=sort,
#    7117         )
#    7118
#
# ~\Anaconda3\envs\venv_ml\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     253         verify_integrity=verify_integrity,
#     254         copy=copy,
# --> 255         sort=sort,
#     256     )
#     257
#
# ~\Anaconda3\envs\venv_ml\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     426         self.copy = copy
#     427
# --> 428         self.new_axes = self._get_new_axes()
#     429
#     430     def get_result(self):
#
# ~\Anaconda3\envs\venv_ml\lib\site-packages\pandas\core\reshape\concat.py in _get_new_axes(self)
#     520                 new_axes[i] = ax
#     521
# --> 522         new_axes[self.axis] = self._get_concat_axis()
#     523         return new_axes
#     524
#
# ~\Anaconda3\envs\venv_ml\lib\site-packages\pandas\core\reshape\concat.py in _get_concat_axis(self)
#     568             indexes = [x._data.axes[self.axis] for x in self.objs]
#     569
# --> 570         if self.ignore_index:
#     571             idx = ibase.default_index(sum(len(i) for i in indexes))
#     572             return idx
#
# ~\Anaconda3\envs\venv_ml\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1554             "The truth value of a {0} is ambiguous. "
#    1555             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1556                 self.__class__.__name__
#    1557             )
#    1558         )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
data.con
# Out:
#          time     X_value       Y_value  Z_value
# 0    Started:  8월 19 2019  15:08:56:766
# 1      0.0000     0.00000       0.00000  0.00000
# 2      0.0052    -0.03972      -0.34664  0.26586
# 3      0.0451    -0.12008      -0.25417  0.51786
# 4      0.0848    -0.13013      -0.16888  0.48568
# ..        ...         ...           ...      ...
# 113    4.4661    -2.76631      -1.35828  1.82010
# 114    4.5030    -2.47535      -1.29011  1.42082
# 115    4.5448    -2.08231      -1.22664  1.56850
# 116    4.5826    -1.77547      -1.14557  1.10392
# 117    4.6223    -1.41437      -1.06624  1.04742
#
# [118 rows x 4 columns]
