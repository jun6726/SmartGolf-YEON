# %%
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
import matplotlib.animation as animation
from IPython.display import HTML

# %%
from glob import glob
from os import path
from pandas import read_csv, concat
from csv import writer
import basicfunc2

# %%
def update_lines(num, dataLines, lines):
    for line, data in zip(lines, dataLines):
        # NOTE: there is no .set_data() for 3 dim data...
        line.set_data(data[0:2, :num])
        line.set_3d_properties(data[2, :num])
        #line.set_marker("o")
    return lines

# %%
tempdf=read_csv('./csv/lasttesting/Golf_6.csv',header=0)
tempdf.fillna(0,inplace=True)

# %%
tempdf = tempdf.iloc[:,1:4].astype(float)
#tempdf = basicfunc2.resizedataseq(tempdf,150)
len(tempdf)
# Out:
# 203

# %%
tempdf.shape
# Out:
# (203, 3)

# %%
data.shape
# Out:
# (1, 3, 212)

# %%
testing = tempdf.values
testing = np.transpose(testing)
#testing = testing[np.newaxis]
testing.shape
# Out:
# (3, 203)

# %%
for dat in data:
    print(dat.shape)
# Out:
# (3, 212)

# %%
x1 = testing[0][1]

# %%
# Attaching 3D axis to the figure
#fig = plt.figure()
fig = plt.figure(figsize=(10,15))
ax = p3.Axes3D(fig)



#you should modify here!!!!!!
# Lines to plot in 3D
t = np.linspace(-2*np.pi,2*np.pi,50)
x1, y1, z1 = np.cos(t), np.sin(t), t/t.max()  #50개씩... .내경우 140개씩.
x2, y2, z2 = t/t.max(), np.cos(t), np.sin(t)
data = np.array([[x1,y1,z1],[x2,y2,z2]])

x1,y1,z1 =testing[0],testing[1],testing[2]
data=(np.array([x1,y1,z1]))
data=data[np.newaxis]


# NOTE: Can't pass empty arrays into 3d version of plot()
#lines = [ax.plot(dat[0, 0:1], dat[1, 0:1], dat[2, 0:1])[0] for dat in data]
lines = [ax.plot(dat[2, 0:1], dat[0, 0:1], dat[1, 0:1])[0] for dat in data]

#ax.set_xlim(-1.1,1.1)
#ax.set_ylim(-1.1,1.1)
#ax.set_zlim(-1.1,1.1)

ax.set_xlim(-1.5,1.5)
ax.set_ylim(-1.5,1.5)
ax.set_zlim(-1.5,1.5)
ax.set_xlabel("z")
ax.set_ylabel("x")
ax.set_zlabel("y")
#ax.view_init(elev=1,azim=1)
#ax.view_init(azim=0,elev=10)
plt.rcParams['animation.html'] = 'html5'

line_ani = animation.FuncAnimation(fig, update_lines, 50, fargs=(data, lines),
                                   interval=100, blit=True, repeat=True)

# The empty figure shown below is unknown.
# Does anyone know how to delete this?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-176-1fddeca9f5f2> in <module>
#      20 # NOTE: Can't pass empty arrays into 3d version of plot()
#      21 #lines = [ax.plot(dat[0, 0:1], dat[1, 0:1], dat[2, 0:1])[0] for dat in data]
# ---> 22 lines = [ax.scatter(dat[2, 0:1], dat[0, 0:1], dat[1, 0:1])[0] for dat in data]
#      23
#      24 #ax.set_xlim(-1.1,1.1)
#
# <ipython-input-176-1fddeca9f5f2> in <listcomp>(.0)
#      20 # NOTE: Can't pass empty arrays into 3d version of plot()
#      21 #lines = [ax.plot(dat[0, 0:1], dat[1, 0:1], dat[2, 0:1])[0] for dat in data]
# ---> 22 lines = [ax.scatter(dat[2, 0:1], dat[0, 0:1], dat[1, 0:1])[0] for dat in data]
#      23
#      24 #ax.set_xlim(-1.1,1.1)
#
# TypeError: 'Path3DCollection' object is not subscriptable

# %%
#lines = [ax.plot(dat[0, 0:1], dat[1, 0:1], dat[2, 0:1])[0] for dat in data]
type(lines) #list
print(len(lines)) #2
print(type(lines[0])) # Line 3D
# Out:
# 1
# <class 'mpl_toolkits.mplot3d.art3d.Line3D'>

# %%
data.shape
# Out:
# (1, 3, 203)

# %%
x1,y1,z1 =testing[0],testing[1],testing[2]
data=(np.array([x1,y1,z1]))
data.shape
# Out:
# (3, 203)

# %%
testing[0][0]
# Out:
# 0.0

# %%
data.shape
# Out:
# (3, 203)

# %%
line_ani
# Out:
# <video width="720" height="1080" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
line_ani.save('line_animation_3d_funcanimation.mp4', writer='ffmpeg',fps=1000/100)
line_ani.save('line_animation_3d_funcanimation.gif', writer='imagemagick',fps=1000/100)
# Out:
# MovieWriter imagemagick unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.

# %%
tempdf=read_csv('./csv/test-20.csv',header=0)
tempdf.fillna(0,inplace=True)
tempdf.head()
# Out:
#         Time     GyroX     GyroY     GyroZ      PosX      PosY      PosZ  \
# 0   Started:  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  2.46315E7  0.604250 -0.539516 -0.678169  0.000000  0.000000  0.600000
# 2  2.46315E7  0.604250 -0.636644 -0.571267  0.000000  0.000000  0.600000
# 3  2.46315E7  0.676943 -0.286618 -0.571267  0.000000  0.000000  0.600000
# 4  2.46315E7  0.676943  0.219178 -1.011701 -0.000123 -0.010537  0.599907
#
#      ForPie    ForThe  Unnamed: 9  Unnamed: 10
# 0  0.000000  0.000000         0.0          0.0
# 1  0.000000  0.000000         0.0          0.0
# 2  0.000000  0.000000         0.0          0.0
# 3  0.000000  0.000000         0.0          0.0
# 4 -0.029764 -7.801945         0.0          0.0

# %%
tempdf = tempdf.iloc[:,4:7].astype(float)
#tempdf = basicfunc2.resizedataseq(tempdf,150)
len(tempdf)
# Out:
# 212

# %%
testing = tempdf.values
testing = np.transpose(testing)
#testing = testing[np.newaxis]
testing.shape
# Out:
# (3, 212)

# %%
fig = plt.figure(figsize=(10,15))
ax = p3.Axes3D(fig)



#you should modify here!!!!!!
# Lines to plot in 3D
t = np.linspace(-2*np.pi,2*np.pi,50)
x1, y1, z1 = np.cos(t), np.sin(t), t/t.max()  #50개씩... .내경우 140개씩.
x2, y2, z2 = t/t.max(), np.cos(t), np.sin(t)
data = np.array([[x1,y1,z1],[x2,y2,z2]])

x1,y1,z1 =testing[0],testing[1],testing[2]
data=(np.array([x1,y1,z1]))
data=data[np.newaxis]

#x1,y1,z1 =testing[0],testing[1],testing[2]

# NOTE: Can't pass empty arrays into 3d version of plot()
#lines = [ax.plot(dat[0, 0:1], dat[1, 0:1], dat[2, 0:1])[0] for dat in data]
lines = [ax.plot(dat[0, 0:1], dat[1, 0:1], dat[2, 0:1])[0] for dat in data]

#ax.set_xlim(-1.1,1.1)
#ax.set_ylim(-1.1,1.1)
#ax.set_zlim(-1.1,1.1)

ax.set_xlim(-1.1,0.5)
ax.set_ylim(-1.1,0.5)
ax.set_zlim(-1.1,0.5)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
#ax.view_init(elev=1,azim=1)
#ax.view_init(elev=90,azim=90)
plt.rcParams['animation.html'] = 'html5'

line_ani = animation.FuncAnimation(fig, update_lines, 50, fargs=(data, lines),
                                   interval=100, blit=True, repeat=True)

# The empty figure shown below is unknown.
# Does anyone know how to delete this?

# %%
line_ani
# Out:
# <video width="720" height="1080" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
tempdf=read_csv('./csv/test-20.csv',header=0)
tempdf.fillna(0,inplace=True)

# %%
tempdf.head()
# Out:
#         Time     GyroX     GyroY     GyroZ      PosX      PosY      PosZ  \
# 0   Started:  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  2.46315E7  0.604250 -0.539516 -0.678169  0.000000  0.000000  0.600000
# 2  2.46315E7  0.604250 -0.636644 -0.571267  0.000000  0.000000  0.600000
# 3  2.46315E7  0.676943 -0.286618 -0.571267  0.000000  0.000000  0.600000
# 4  2.46315E7  0.676943  0.219178 -1.011701 -0.000123 -0.010537  0.599907
#
#      ForPie    ForThe  Unnamed: 9  Unnamed: 10
# 0  0.000000  0.000000         0.0          0.0
# 1  0.000000  0.000000         0.0          0.0
# 2  0.000000  0.000000         0.0          0.0
# 3  0.000000  0.000000         0.0          0.0
# 4 -0.029764 -7.801945         0.0          0.0

# %%
tempdf = tempdf.iloc[:,4:7].astype(float)
#tempdf = basicfunc2.resizedataseq(tempdf,150)
len(tempdf)
# Out:
# 212

# %%
testing = tempdf.values
testing = np.transpose(testing)
#testing = testing[np.newaxis]
testing.shape
# Out:
# (3, 212)

# %%
x1,y1,z1 =testing[0],testing[1],testing[2]

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(z1, x1, y1, c='b', s=60)
#ax.plot(x1,y1,z1)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
#ax.view_init(180,270)
#ax.view_init(180,180)
#ax.view_init(0,90)
plt.title("Swing")
plt.show()

# %%
tempdf=read_csv('./csv/PertingData/Golf_5.csv',header=0)
#tempdf=read_csv('./csv/test-20.csv',header=0)

tempdf.fillna(0,inplace=True)

# %%
tempdf = tempdf.iloc[:,4:7].astype(float)
#tempdf = basicfunc2.resizedataseq(tempdf,150)
len(tempdf)
# Out:
# 123

# %%
testing = tempdf.values
testing = np.transpose(testing)
#testing = testing[np.newaxis]
testing.shape
# Out:
# (3, 123)

# %%
x1,y1,z1 =testing[0],testing[1],testing[2]

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(z1, x1, y1, c='b', s=60)
#ax.plot(x1,y1,z1)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
#ax.view_init(180,270)
#ax.view_init(180,180)
#ax.view_init(0,90)
#ax.view_init(30,-90)
ax.view_init(30,45)
plt.title("Perting")
plt.show()

# %%
#fig = plt.figure(figsize=(10,10))
fig=plt.figure()
#ax = fig.add_subplot(111, projection = '3d')
ax = p3.Axes3D(fig)
plt.scatter(x1,y1,z1,s=5)
#plt.plot(x1,y1,z1,c='b')
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
#p3.scatter( x1,y1,z1,s=20 )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-151-5b79ff421c60> in <module>
#       3 #ax = fig.add_subplot(111, projection = '3d')
#       4 ax = p3.Axes3D(fig)
# ----> 5 plt.scatter(x1,y1,z1,s=5)
#       6 #plt.plot(x1,y1,z1,c='b')
#       7 ax.set_xlabel("x")
#
# TypeError: scatter() got multiple values for argument 's'
